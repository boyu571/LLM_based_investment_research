# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# 데이터 로드
data = pd.read_csv(r'C:\Users\user\boyu571_github\01_Kakaobank_SKKU_Research_23\eng_20.csv')

# 형태소 분석기 초기화
okt = Okt()

# 기사의 내용을 형태소로 분석
data['tokenized_content'] = data['content'].apply(lambda x: ' '.join(okt.morphs(x)))

# TF-IDF 변환기를 초기화
tfidf_vectorizer = TfidfVectorizer()

# 형태소 분석된 내용을 벡터로 변환
tfidf_matrix = tfidf_vectorizer.fit_transform(data['tokenized_content'])

# 코사인 유사도 행렬 계산
cosine_sim = cosine_similarity(tfidf_matrix)

# 행렬의 통계 값 계산
# Compute statistics for the matrix
min_value = round(np.min(cosine_sim), 4)
max_value = round(np.max(cosine_sim), 4)
mean_value = round(np.mean(cosine_sim), 4)
median_value = round(np.median(cosine_sim), 4)
std_value = round(np.std(cosine_sim), 4)

min_value, max_value, mean_value, median_value, std_value
# Out:
# (0.0127, 1.0, 0.2894, 0.1647, 0.3401)

# %%
len(data)
# Out:
# 10

# %%
# 군집화
clusters = []
visited = np.zeros(cosine_sim.shape[0], dtype=bool)
for i in range(cosine_sim.shape[0]):
    if not visited[i]:
        similar_articles = np.where(cosine_sim[i] > 0.6)[0]
        clusters.append(similar_articles)
        visited[similar_articles] = True

# 각 군집에서 대표 기사만 남기기
representative_indices = [cluster[0] for cluster in clusters if len(cluster) > 0]

# 대표 기사만 포함된 데이터프레임 생성
filtered_data = data.iloc[representative_indices].reset_index(drop=True)
print(len(filtered_data))
filtered_data
# Out:
# 6
#                   time                                title  \
# 0  2017-11-04 09:56:45              잠잠한 북한…트럼프 순방기간 도발 가능성은
# 1  2017-11-04 09:01:08          CME 비트코인 거래 개시 소식에 계좌 개설 열풍
# 2  2017-11-04 15:37:27           스파크랩, 1천억 규모 블록체인 투자 펀드 출범
# 3  2017-11-04 19:55:00         "현직 경찰관에 배우 동원까지"…가상화폐 범죄 기승
# 4  2017-11-05 01:34:20                  가상화폐, 금융시장의 새로운 쓰나미
# 5  2017-11-05 06:00:00  [박수찬의 軍]대통령 공약과 따로 노는 국방부의 北 미사일 대책
#
#                                              content         press  \
# 0  \r\n\t\t\t잠잠한 북한…트럼프 순방기간 도발 가능성은[앵커] 북한은 최근 5...  연합뉴스TV언론사 선정
# 1  \n\n\n\n\n[아시아경제 황준호 기자]  세계 최대 파생상품 거래소인 미국 시...         아시아경제
# 2  \n\t\t\t 스파크랩 그룹은 블록체인과 암호화 화폐 기업 투자 펀드인 ‘스파크체...        파이낸셜뉴스
# 3  \r\n\t\t\t【 앵커멘트 】  하루 거래액이 2조 원을 넘어서면서 비트코인 등...           MBN
# 4  \r\n비트코인·이더리움 등 1000종류상위 10개 시가총액만 150조원빠르고 거래...      T19면 TOP
# 5  \r\n\r\n\r\n\r\n\r\n천궁 지대공미사일이 2일 충남 보령 대천사격장에...    세계일보언론사 선정
#
#                                                 link             UTC-time  \
# 0  https://n.news.naver.com/mnews/article/422/000...  2017-11-04 00:56:45
# 1  https://n.news.naver.com/mnews/article/277/000...  2017-11-04 00:01:08
# 2  https://n.news.naver.com/mnews/article/014/000...  2017-11-04 06:37:27
# 3  https://n.news.naver.com/mnews/article/057/000...  2017-11-04 10:55:00
# 4  https://n.news.naver.com/mnews/article/353/000...  2017-11-04 16:34:20
# 5  https://n.news.naver.com/mnews/article/022/000...  2017-11-04 21:00:00
#
#      UTC-date                                  tokenized_content
# 0  2017-11-04  \r\n\t\t\t 잠잠한 북한 … 트럼프 순방 기간 도발 가능성 은 [ 앵커 ] ...
# 1  2017-11-04  \n\n\n\n\n [ 아시아 경제 황준호 기자 ] 세계 최대 파생상품 거래소 인 ...
# 2  2017-11-04  \n\t\t\t  스파크 랩 그룹 은 블록 체인 과 암호 화 화폐 기업 투자 펀드 ...
# 3  2017-11-04  \r\n\t\t\t 【 앵커 멘트 】 하루 거래 액 이 2조 원 을 넘어서면서 비트...
# 4  2017-11-04  \r\n 비트코인 · 이 더 리움 등 1000 종류 상위 10 개 시가총액 만 15...
# 5  2017-11-04  \r\n\r\n\r\n\r\n\r\n 천궁 지 대 공 미사일 이 2일 충남 보령 대...

# %%
filtered_data.to_csv('filtered_20171104_01.csv', encoding='utf-8-sig', index=False)

# %%
data = pd.read_csv(r'C:\Users\user\boyu571_github\01_Kakaobank_SKKU_Research_23\eng_20.csv', lineterminator='\n')
data
# Out:
#                                                source  \
# 0                    {'id': None, 'name': "Barron's"}
# 1               {'id': None, 'name': 'Bitrebels.com'}
# 2              {'id': None, 'name': 'Independent.ie'}
# 3          {'id': None, 'name': 'New Zealand Herald'}
# 4       {'id': None, 'name': 'Sputnik International'}
# 5                     {'id': None, 'name': 'newsBTC'}
# 6         {'id': None, 'name': 'Yahoo Entertainment'}
# 7   {'id': 'the-irish-times', 'name': 'The Irish T...
# 8                     {'id': None, 'name': 'newsBTC'}
# 9                    {'id': None, 'name': 'CoinDesk'}
# 10                   {'id': None, 'name': 'CoinDesk'}
# 11                    {'id': None, 'name': 'newsBTC'}
# 12  {'id': 'the-globe-and-mail', 'name': 'The Glob...
# 13  {'id': 'business-insider', 'name': 'Business I...
# 14                    {'id': None, 'name': 'newsBTC'}
# 15               {'id': 'fortune', 'name': 'Fortune'}
# 16                    {'id': None, 'name': 'newsBTC'}
# 17                    {'id': None, 'name': 'newsBTC'}
# 18                    {'id': None, 'name': 'DailyFX'}
# 19                  {'id': None, 'name': 'The Punch'}
#
#                                  author  \
# 0                                Ed Lin
# 1                        Brenda Vollman
# 2                          Sean O'Grady
# 3              newsfeeds@nzherald.co.nz
# 4                               Sputnik
# 5                        Dalmas Ngetich
# 6                                   NaN
# 7                       Aifric Campbell
# 8                               Rick D.
# 9                         Alyssa Hertig
# 10                           Leigh Cuen
# 11                         Martin Young
# 12                   The Globe And Mail
# 13         Business Insider Deutschland
# 14                        Tony Spilotro
# 15         Clay Chandler, Eamon Barrett
# 16                        Cole Petersen
# 17                      Ricardo Esteves
# 18  David Cottle, Analyst, David Cottle
# 19                          Taiwo Ojoye
#
#                                                 title  \
# 0                       Hunting for Undervalued REITs
# 1   5 Great Reasons To Buy And Hold Cryptocurrenci...
# 2               Westlife star warns fans off Web scam
# 3          Comment: Euro pipe dream holds no currency
# 4   OAS Chief Not Ruling Out Military Invasion of ...
# 5   Cardano Price Analysis: Cardano Buyers Accumulate
# 6   Bitcoin Cash, Litecoin and Ripple Daily Analys...
# 7   Crash, Crisis, Crypto: a short history of inve...
# 8   Bitcoin Hit $20k in 2017 Without Institutions,...
# 9   Grin Is Hard Forking Every Six Months to Keep ...
# 10  Coinbase's New NYC Office to Hire 100 in Wall ...
# 11  Cryptocurrency Market Update: Tezos Jumps 25% ...
# 12  Canada emerges as a hub for blockchain technology
# 13  There's a clever psychological reason why Amaz...
# 14  Firefox, Brave Browser Creator: We HODL Crypto...
# 15   Mangkhut, Apple, and Google: The Gathering Storm
# 16  Ex-CEO of Crypto Company Sentenced to Prison f...
# 17  ECB Has No Plans to Launch Digital Currency Du...
# 18  Australian Dollar Remains Pressured But May Ge...
# 19    Technology, INEC and the 2019 general elections
#
#                                           description  \
# 0   Stiller Beobachter | Flickr Stiller Beobachter...
# 1   How many times have you heard someone say that...
# 2   Singer Shane Filan has warned his fans about a...
# 3   COMMENT: Over the next ten years, it will beco...
# 4   The head of the Organization of American State...
# 5   There are low time frame recoveries but it loo...
# 6   It’s a positive start to the weekend for the m...
# 7   Short story by Aifric Campbell marking the 10t...
# 8   Despite an overwhelming sense of bearishness i...
# 9   Amid crypto's war on ASICs, the Grin community...
# 10  Crypto industry unicorn Coinbase has aggressiv...
# 11  FOMO Moments Markets are pretty flat this Satu...
# 12  Young innovators started things rolling a few ...
# 13  methodshop.com/Flickr Amazon, Apple, Microsoft...
# 14  The creator of Brave Browser, Firefox, and the...
# 15  The special Sino Saturday edition of our popul...
# 16  The former CEO of a cryptocurrency company has...
# 17  The European Central Bank (ECB) is not issuing...
# 18  The Australian Dollar has swooned this year de...
# 19  Chukwuemeka Fred Agbata Jnr. Election fever is...
#
#                                                   url  \
# 0   https://www.barrons.com/articles/hunting-for-u...
# 1   http://www.bitrebels.com/business/5-reasons-bu...
# 2   https://www.independent.ie/irish-news/westlife...
# 3   https://www.nzherald.co.nz/business/news/artic...
# 4   https://sputniknews.com/latam/2018091510680529...
# 5   https://www.newsbtc.com/2018/09/15/cardano-pri...
# 6   https://finance.yahoo.com/news/bitcoin-cash-li...
# 7   https://www.irishtimes.com/culture/books/crash...
# 8   https://www.newsbtc.com/2018/09/15/bitcoin-hit...
# 9   https://www.coindesk.com/grin-is-hard-forking-...
# 10  https://www.coindesk.com/coinbase-crypto-jobs-...
# 11  https://www.newsbtc.com/2018/09/15/cryptocurre...
# 12  https://www.theglobeandmail.com/business/artic...
# 13  https://www.businessinsider.com/theres-psychol...
# 14  https://www.newsbtc.com/2018/09/15/firefox-bra...
# 15  http://fortune.com/2018/09/15/mangkhut-apple-a...
# 16  https://www.newsbtc.com/2018/09/15/ex-ceo-of-c...
# 17  https://www.newsbtc.com/2018/09/15/ecb-has-no-...
# 18  https://www.dailyfx.com/forex/fundamental/fore...
# 19  https://punchng.com/technology-inec-and-the-20...
#
#                                            urlToImage  \
# 0   https://asset.barrons.com/public/resources/ima...
# 1   http://www.bitrebels.com/wp-content/uploads/20...
# 2   https://www.independent.ie/incoming/article373...
# 3   https://www.nzherald.co.nz/resizer/MrJmsEMrF2l...
# 4   https://cdn5.img.sputniknews.com/images/106755...
# 5   https://s3.amazonaws.com/main-newsbtc-images/2...
# 6   https://s.yimg.com/uu/api/res/1.2/qjRDFY7ZdfVP...
# 7   https://www.irishtimes.com/image-creator/?id=1...
# 8   https://s3.amazonaws.com/main-newsbtc-images/2...
# 9   https://media.coindesk.com/uploads/2018/09/raz...
# 10  https://media.coindesk.com/uploads/2018/09/Ada...
# 11  https://s3.amazonaws.com/main-newsbtc-images/2...
# 12  https://www.theglobeandmail.com/resizer/dw0CqG...
# 13  https://amp.businessinsider.com/images/5b9bbcd...
# 14  https://s3.amazonaws.com/main-newsbtc-images/2...
# 15  https://fortunedotcom.files.wordpress.com/2017...
# 16  https://s3.amazonaws.com/main-newsbtc-images/2...
# 17  https://s3.amazonaws.com/main-newsbtc-images/2...
# 18                                                NaN
# 19  https://cdn.punchng.com/wp-content/uploads/201...
#
#                          time  \
# 0   2018-09-15 00:45:26+00:00
# 1   2018-09-15 01:00:21+00:00
# 2   2018-09-15 01:30:00+00:00
# 3   2018-09-15 01:34:39+00:00
# 4   2018-09-15 01:56:00+00:00
# 5   2018-09-15 02:00:07+00:00
# 6   2018-09-15 03:58:52+00:00
# 7   2018-09-15 05:00:00+00:00
# 8   2018-09-15 08:30:54+00:00
# 9   2018-09-15 09:15:21+00:00
# 10  2018-09-15 10:00:01+00:00
# 11  2018-09-15 10:00:34+00:00
# 12  2018-09-15 10:31:43+00:00
# 13  2018-09-15 11:00:00+00:00
# 14  2018-09-15 12:22:38+00:00
# 15  2018-09-15 14:08:16+00:00
# 16  2018-09-15 18:45:36+00:00
# 17  2018-09-15 20:30:05+00:00
# 18  2018-09-15 22:00:00+00:00
# 19  2018-09-15 23:15:52+00:00
#
#                                               content                  press  \
# 0   Shares of real estate investment trusts have s...               Barron's
# 1   How many times have you heard someone say that...          Bitrebels.com
# 2   Singer Shane Filan has warned his fans about a...         Independent.ie
# 3   COMMENT: Over the next ten years, it will beco...     New Zealand Herald
# 4   The head of the Organization of American State...  Sputnik International
# 5   There are low time frame recoveries but it loo...                newsBTC
# 6   Bitcoin Cash Resumes Recovery Bitcoin Cash fel...    Yahoo Entertainment
# 7   I walk into the den where my two girls are lyi...        The Irish Times
# 8   Despite an overwhelming sense of bearishness i...                newsBTC
# 9   The Grin community is trying to keep ASICs awa...               CoinDesk
# 10  The crypto industry unicorn Coinbase has aggre...               CoinDesk
# 11  Markets are pretty flat this Saturday; Tezos, ...                newsBTC
# 12  From bitcoin to Zcash, the world’s cryptocurre...     The Globe And Mail
# 13  The future of technology is female — or at lea...       Business Insider
# 14  The creator of Brave Browser, Firefox, and the...                newsBTC
# 15  And the forty thieves? Ant Financial, Alibaba’...                Fortune
# 16  The former CEO of a cryptocurrency company has...                newsBTC
# 17  The European Central Bank (ECB) is not issuing...                newsBTC
# 18  Fundamental Australian Dollar Forecast: Neutra...                DailyFX
# 19  Chukwuemeka Fred Agbata Jnr. Election fever is...              The Punch
#
#                                          content_full        date\r
# 0   Shares of real estate investment trusts have s...  2018-09-15\r
# 1   How many times have you heard someone say that...  2018-09-15\r
# 2   Singer Shane Filan has warned his fans about a...  2018-09-15\r
# 3   COMMENT: Over the next ten years, it will beco...  2018-09-15\r
# 4   "With regards to a military intervention aimed...  2018-09-15\r
# 5   There are low time frame recoveries but it loo...  2018-09-15\r
# 6   Bitcoin Cash Resumes RecoveryBitcoin Cash fell...  2018-09-15\r
# 7   I walk into the den where my two girls are lyi...  2018-09-15\r
# 8   Despite an overwhelming sense of bearishness i...  2018-09-15\r
# 9   The Grin community is trying to keep ASICs awa...  2018-09-15\r
# 10  The crypto industry unicorn Coinbase has aggre...  2018-09-15\r
# 11  FOMO Moments Markets are pretty flat this Satu...  2018-09-15\r
# 12  From bitcoin to Zcash, the world’s cryptocurre...  2018-09-15\r
# 13  The future of technology is female — or at lea...  2018-09-15\r
# 14  The creator of Brave Browser, Firefox, and the...  2018-09-15\r
# 15  And the forty thieves? Ant Financial, Alibaba’...  2018-09-15\r
# 16  The former CEO of a cryptocurrency company has...  2018-09-15\r
# 17  The European Central Bank (ECB) is not issuing...  2018-09-15\r
# 18  Fundamental Australian Dollar Forecast: Neutra...  2018-09-15\r
# 19  Chukwuemeka Fred Agbata Jnr. Election fever is...  2018-09-15\r

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import numpy as np
from nltk.tokenize import sent_tokenize
import torch

# 필요한 경우 NLTK 데이터를 다운로드합니다.
import nltk

# 데이터 로드
data = pd.read_csv(r'C:\Users\user\boyu571_github\01_Kakaobank_SKKU_Research_23\eng_250.csv', lineterminator='\n')

# sBERT 모델 로드
model = SentenceTransformer('paraphrase-distilroberta-base-v1')

# 문서를 문장으로 나누고 각 문장에 대해 임베딩을 생성합니다.
document_embeddings = []
for content in data['content_full']:
    sentences = sent_tokenize(content)  # 문장으로 분할
    sentence_embeddings = model.encode(sentences, convert_to_tensor=True)  # 문장 임베딩 생성
    document_embedding = torch.mean(sentence_embeddings, dim=0)  # 문장 임베딩을 합산하여 문서 임베딩 생성
    document_embeddings.append(document_embedding)

# 문서 임베딩으로 유사도 행렬을 계산합니다.
similarity_matrix = []
for embedding1 in document_embeddings:
    row = []
    for embedding2 in document_embeddings:
        similarity = util.pytorch_cos_sim(embedding1, embedding2).item()
        row.append(similarity)
    similarity_matrix.append(row)

# 행렬의 통계 값 계산
min_value = round(np.min(similarity_matrix), 4)
max_value = round(np.max(similarity_matrix), 4)
mean_value = round(np.mean(similarity_matrix), 4)
median_value = round(np.median(similarity_matrix), 4)
std_value = round(np.std(similarity_matrix), 4)

min_value, max_value, mean_value, median_value, std_value
# Out:
# (0.0098, 1.0, 0.4499, 0.4469, 0.1273)

# %%
from nltk.tokenize import sent_tokenize

# Assuming 'data' contains full articles, not individual sentences
sentences = [sent_tokenize(article) for article in data['content_full'].tolist()]

# Flatten the list of lists into a single list of sentences
sentences = [sentence for sublist in sentences for sentence in sublist]

# Now encode these sentences
embeddings = model.encode(sentences, convert_to_tensor=True)

# %%
# 군집화
clusters = []
visited = np.zeros(len(data), dtype=bool)
for i in range(len(data)):
    if not visited[i]:
        similar_articles = np.where(np.array(similarity_matrix[i]) > 0.6)[0]
        clusters.append(similar_articles)
        visited[similar_articles] = True

# 각 군집에서 대표 기사만 남기기
representative_indices = [cluster[0] for cluster in clusters if len(cluster) > 0]

# 대표 기사만 포함된 데이터프레임 생성
filtered_data = data.iloc[representative_indices].reset_index(drop=True)
print(len(filtered_data))
filtered_data
# Out:
# 79
#                                       source                       author  \
# 0       {'id': None, 'name': 'OilPrice.com'}                Simon Watkins
# 1         {'id': None, 'name': 'Bitcoinist'}                   Samuel Wan
# 2      {'id': None, 'name': 'Seeking Alpha'}               SA Transcripts
# 3   {'id': None, 'name': 'Activistpost.com'}                Activist Post
# 4           {'id': None, 'name': 'Wccftech'}              Evan Federowicz
# ..                                       ...                          ...
# 74    {'id': 'newsweek', 'name': 'Newsweek'}                    Paul Bond
# 75              {'id': None, 'name': 'CNBC'}               Tanaya Macheel
# 76        {'id': None, 'name': 'Bitcoinist'}                   Bitcoinist
# 77     {'id': None, 'name': 'Cointelegraph'}  Cointelegraph By Yashu Gola
# 78        {'id': None, 'name': 'Tech Times'}                 Joseph Henry
#
#                                                 title  \
# 0   Could Energy Ties Bring Saudi Arabia's Conflic...
# 1   The World Economic Forum’s Cryptocurrency Guid...
# 2   The Walt Disney Company's (DIS) CEO Bob Chapek...
# 3   Millions of Sleep Apnea Machines and Ventilato...
# 4   ASUS Launches Its RTX 30 Series GPUs with Lite...
# ..                                                ...
# 74  Ivory Hecker Says Fox Station Censored Bitcoin...
# 75  Crypto asset manager Bitwise raises $70 millio...
# 76        Bitwells Boosts Your ROI in High Volatility
# 77  This unknown cryptocurrency soared by 164,842%...
# 78  Goldman Sachs to Explore $ETH in the Next Mont...
#
#                                           description  \
# 0   The relationship between the two great indigen...
# 1   The World Economic Forum (WEF) has published i...
# 2   The Walt Disney Company (NYSE:DIS) Credit Suis...
# 3   By B.N. Frank Sleep apnea is common in the U.S...
# 4   ASUS has added new models to its RTX 30 series...
# ..                                                ...
# 74  Ivory Hecker, a reporter for Fox at a Houston ...
# 75  Crypto index fund manager Bitwise raised $70 m...
# 76  Bitcoin dropped nearly 35% in May, marking one...
# 77  One random cryptocurrency's market valuation j...
# 78  Goldman Sachs bank eyes expansion of $ETH for ...
#
#                                                   url  \
# 0   https://oilprice.com/Geopolitics/Middle-East/C...
# 1   https://bitcoinist.com/the-world-economic-foru...
# 2   https://seekingalpha.com/article/4434827-walt-...
# 3   https://www.activistpost.com/2021/06/millions-...
# 4   https://wccftech.com/asus-launches-its-rtx-30-...
# ..                                                ...
# 74  https://www.newsweek.com/ivory-hecker-says-fox...
# 75  https://www.cnbc.com/2021/06/15/crypto-asset-m...
# 76  https://bitcoinist.com/bitwells-boosts-your-ro...
# 77  https://cointelegraph.com/news/this-unknown-cr...
# 78  https://www.techtimes.com/articles/261443/2021...
#
#                                            urlToImage  \
# 0   https://d32r1sh890xpii.cloudfront.net/article/...
# 1   https://bitcoinist.com/wp-content/uploads/2021...
# 2   https://static.seekingalpha.com/assets/og_imag...
# 3   https://www.activistpost.com/wp-content/upload...
# 4   https://cdn.wccftech.com/wp-content/uploads/20...
# ..                                                ...
# 74  https://d.newsweek.com/en/full/1822110/james-o...
# 75  https://image.cnbcfm.com/api/v1/image/10689088...
# 76  https://bitcoinist.com/wp-content/uploads/2021...
# 77  https://images.cointelegraph.com/images/1200_a...
# 78  https://1734811051.rsc.cdn77.org/data/images/f...
#
#                          time  \
# 0   2021-06-15 00:00:00+00:00
# 1   2021-06-15 00:00:57+00:00
# 2   2021-06-15 00:01:09+00:00
# 3   2021-06-15 00:37:15+00:00
# 4   2021-06-15 00:39:11+00:00
# ..                        ...
# 74  2021-06-15 22:01:48+00:00
# 75  2021-06-15 12:41:03+00:00
# 76  2021-06-15 17:14:15+00:00
# 77  2021-06-15 07:30:00+00:00
# 78  2021-06-15 00:40:00+00:00
#
#                                               content             press  \
# 0   Saudi Arabia is sidelining itself…\r\nIran is ...      OilPrice.com
# 1   The World Economic Forum (WEF) has published i...        Bitcoinist
# 2   The Walt Disney Company (NYSE:DIS) Credit Suis...     Seeking Alpha
# 3   By B.N. Frank\r\nSleep apnea is common in the ...  Activistpost.com
# 4   ASUS has added new models to its RTX 30 series...          Wccftech
# ..                                                ...               ...
# 74  Houston TV reporter Ivory Hecker on Tuesday re...          Newsweek
# 75  Henry Kravis, Stanley Druckenmiller and Bridge...              CNBC
# 76  Bitcoin dropped nearly 35% in May, marking one...        Bitcoinist
# 77  About $7.65 billion entered the cryptocurrency...     Cointelegraph
# 78  Ethereum was seen to be a potential cryptocurr...        Tech Times
#
#                                          content_full        date\r
# 0   The relationship between the two great indigen...  2021-06-15\r
# 1   The World Economic Forum (WEF) has published i...  2021-06-15\r
# 2   The Walt Disney Company (NYSE:DIS) Credit Suis...  2021-06-15\r
# 3   By B.N. Frank Sleep apnea is common in the U.S...  2021-06-15\r
# 4   ASUS has added new models to its RTX 30 series...  2021-06-15\r
# ..                                                ...           ...
# 74  Houston TV reporter Ivory Hecker released Tues...  2021-06-15\r
# 75  Henry Kravis, Stanley Druckenmiller and Bridge...  2021-06-15\r
# 76  Bitcoin dropped nearly 35% in May, marking one...  2021-06-15\r
# 77  About $7.65 billion entered the cryptocurrency...  2021-06-15\r
# 78  Ethereum was seen to be a potential cryptocurr...  2021-06-15\r
#
# [79 rows x 11 columns]

# %%
filtered_data.to_csv('filtered_20171104_02.csv', encoding='utf-8-sig', index=False)

# %%
# Restricted Damerau-Levenshtein distance 계산 함수
def restricted_damerau_levenshtein(s1: str, s2: str) -> int:
    len_str1 = len(s1)
    len_str2 = len(s2)
    d_matrix = [[0 for _ in range(len_str2 + 1)] for _ in range(len_str1 + 1)]

    for i in range(len_str1 + 1):
        d_matrix[i][0] = i
    for j in range(len_str2 + 1):
        d_matrix[0][j] = j

    for i in range(1, len_str1 + 1):
        for j in range(1, len_str2 + 1):
            cost = 0 if s1[i - 1] == s2[j - 1] else 1
            d_matrix[i][j] = min(
                d_matrix[i - 1][j] + 1,  # Deletion
                d_matrix[i][j - 1] + 1,  # Insertion
                d_matrix[i - 1][j - 1] + cost  # Substitution
            )
            if i > 1 and j > 1 and s1[i - 1] == s2[j - 2] and s1[i - 2] == s2[j - 1]:
                d_matrix[i][j] = min(
                    d_matrix[i][j],
                    d_matrix[i - 2][j - 2] + cost  # Transposition
                )
    return d_matrix[len_str1][len_str2]

# Restricted Damerau-Levenshtein distance 기반 유사도 계산 함수
def similarity_rdl(s1: str, s2: str) -> float:
    distance = restricted_damerau_levenshtein(s1, s2)
    max_len = max(len(s1), len(s2))
    similarity = 1 - (distance / max_len)
    return similarity

# %%
import numpy as np
import pandas as pd

# 임시 데이터 생성 (예제 목적)
data = pd.read_csv(r'C:\Users\user\boyu571_github\01_Kakaobank_SKKU_Research_23\eng_20.csv', lineterminator='\n')

# Restricted Damerau-Levenshtein distance 기반 유사도 계산 함수
def similarity_rdl(s1: str, s2: str) -> float:
    distance = restricted_damerau_levenshtein(s1, s2)
    # 두 문자열 중 더 긴 쪽의 길이로 정규화
    max_len = max(len(s1), len(s2))
    # 유사도는 1에서 정규화된 거리를 뺀 값으로 정의 (유사도가 높을수록 거리는 낮음)
    similarity = 1 - (distance / max_len)
    return similarity

# 유사도 행렬 초기화
similarity_matrix = np.zeros((len(data), len(data)))

# 모든 기사 쌍에 대해 유사도 계산
for i in range(len(data)):
    for j in range(len(data)):
        similarity_matrix[i][j] = similarity_rdl(data['content_full'][i], data['content_full'][j])

# 유사도가 0.6 이상인 기사들을 군집화
threshold = 0.6
clusters = []
visited = np.zeros(len(data), dtype=bool)
for i in range(len(data)):
    if not visited[i]:
        # i번째 기사와 유사도가 threshold 이상인 기사들의 인덱스를 찾음
        similar_articles_indices = np.where(similarity_matrix[i] >= threshold)[0]
        clusters.append(similar_articles_indices)
        visited[similar_articles_indices] = True

# 각 군집에서 대표 기사만 남기기
representative_indices = [cluster[0] for cluster in clusters if len(cluster) > 0]

# 대표 기사만 포함된 데이터프레임 생성
filtered_data = data.iloc[representative_indices].reset_index(drop=True)

# 결과 출력
len(filtered_data), filtered_data, clusters
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-9974de91b7fa> in <module>
#      20 for i in range(len(data)):
#      21     for j in range(len(data)):
# ---> 22         similarity_matrix[i][j] = similarity_rdl(data['content_full'][i], data['content_full'][j])
#      23
#      24 # 유사도가 0.6 이상인 기사들을 군집화
#
# <ipython-input-17-9974de91b7fa> in similarity_rdl(s1, s2)
#       7 # Restricted Damerau-Levenshtein distance 기반 유사도 계산 함수
#       8 def similarity_rdl(s1: str, s2: str) -> float:
# ----> 9     distance = restricted_damerau_levenshtein(s1, s2)
#      10     # 두 문자열 중 더 긴 쪽의 길이로 정규화
#      11     max_len = max(len(s1), len(s2))
#
# <ipython-input-13-bc1ccc84f0de> in restricted_damerau_levenshtein(s1, s2)
#      14             cost = 0 if s1[i - 1] == s2[j - 1] else 1
#      15             d_matrix[i][j] = min(
# ---> 16                 d_matrix[i - 1][j] + 1,  # Deletion
#      17                 d_matrix[i][j - 1] + 1,  # Insertion
#      18                 d_matrix[i - 1][j - 1] + cost  # Substitution
#
# KeyboardInterrupt:
