# %%
# pip install pickle
import pickle
import pandas as pd

# %%
# pandas 라이브러리가 2.0.0 이상은 되어야 되는것 같습니다.
print(pd.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a367cea8c50> in <module>
# ----> 1 print(pd.__version__)
#
# NameError: name 'pd' is not defined

# %%
# pandas 업그레이드
pip install --upgrade pandas --user

# %%
with open('cmc_data_final2_with_stable.pickle', 'rb') as file:
    # pickle 객체를 로드합니다.
    data = pickle.load(file)

data
# Out:
# C:\Users\user\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
#               date  coin_id      name   symbol        open        high  \
# 0       2013-04-28        1   Bitcoin      BTC  135.300003  135.979996
# 1       2013-04-29        1   Bitcoin      BTC  134.444000  147.488007
# 2       2013-04-30        1   Bitcoin      BTC  144.000000  146.929993
# 3       2013-05-01        1   Bitcoin      BTC  139.000000  139.889999
# 4       2013-05-02        1   Bitcoin      BTC  116.379997  125.599998
# ...            ...      ...       ...      ...         ...         ...
# 7693214 2023-08-24    27900  Ethera X  ETHERAX    0.002020    0.002095
# 7693215 2023-08-25    27900  Ethera X  ETHERAX    0.001620    0.001623
# ...

# %%
data
# Out:
#               date  coin_id      name   symbol        open        high  \
# 0       2013-04-28        1   Bitcoin      BTC  135.300003  135.979996
# 1       2013-04-29        1   Bitcoin      BTC  134.444000  147.488007
# 2       2013-04-30        1   Bitcoin      BTC  144.000000  146.929993
# 3       2013-05-01        1   Bitcoin      BTC  139.000000  139.889999
# 4       2013-05-02        1   Bitcoin      BTC  116.379997  125.599998
# ...            ...      ...       ...      ...         ...         ...
# 7693214 2023-08-24    27900  Ethera X  ETHERAX    0.002020    0.002095
# 7693215 2023-08-25    27900  Ethera X  ETHERAX    0.001620    0.001623
# 7693216 2023-08-26    27900  Ethera X  ETHERAX    0.001525    0.002047
# 7693217 2023-08-27    27900  Ethera X  ETHERAX    0.002042    0.002228
# 7693218 2023-08-28    27900  Ethera X  ETHERAX    0.002227    0.002227
#
#                 low       close      vol        mktcap  \
# 0        132.100006  134.210007     0.00  1.488567e+09
# ...
