# %%
# %pip install --upgrade tiktoken
# Out:
# ...
#      ------------------------------------- 635.3/635.3 kB 10.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 268.3/268.3 kB 8.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
import os
import pandas as pd
import time


openai.api_key = "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"

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message["content"]

# %%
def get_completion_4(prompt, model="gpt-4"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message["content"]

# %%
prompt = "이전까지의 지시는 무시하세요. 다음 내용은 특정 주식에 관한 내용입니다. 다음 내용이 해당 주식 가격에 미치는 영향이 긍정적인지 부정적인지 혹은 중립적인지 분류하고 긍정적이면 1, 부정적이면 -1, 중립적이면 0으로 답변하세요."

# %%
import pandas as pd

# CSV 파일 읽기
data = pd.read_csv('시디즈_토론_test.csv')

# 파일의 첫 5행 출력
data.tail()
# Out:
#                   날짜                          제목  \
# 15  2023.07.26 10:29                     더싸게 더싸게
# 16  2023.07.26 10:07  다른데 무증한다고 약팔던 애덜은  다 어디숨엇냐
# 17  2023.07.25 15:00                         딱봐도
# 18  2023.07.25 14:59                          ㅅㅂ
# 19  2023.07.25 14:15                          이거
#
#                                       내용    조회  공감  비공감
# 15                       싸면좋지.기회가 오고 있다.  1902   4    0
# 16  주댕이 함부로 놀려 남들엮어서 피해보는사람들 한테  맞아 죽어야돼  1642   2    0
# 17                            띄우기전 골파기네ㅋ   846   3    3
# 18                  ㅅㅂ꺼 내가 산 날부터 연짱 떨어지네   507   2    1
# 19                     완젼 병맛같은 주식이네 카~~퉤   464   2    1

# %%
data['result'] = (prompt + '제목:'+data['제목']+ '내용:'+data['내용']).apply(get_completion)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data['result'] = (prompt + '제목:'+data['제목']+ '내용:'+data['내용']).apply(get_completion_4)
#
# File c:\Users\boyu571\anaconda3\envs\commons\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\boyu571\anaconda3\envs\commons\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# ...

# %%
data
# Out:
#                   날짜                          제목  \
# 0   2023.08.10 14:15   [주식의정석]시총1천억밑/주식,손대면 폭망한다
# 1   2023.08.10 14:13     광고충들이 여기저기 다니면서 사라는 종목은
# 2   2023.08.10 13:26                 요새 허위광고 신고가
# 3   2023.08.10 11:19                        여긴
# 4   2023.08.10 11:50                        속지마라
# 5   2023.08.10 11:04           3/25 기업IR에서 말한 무증
# 6   2023.08.10 08:32               실적 발표하면 나락이다!
# 7   2023.08.09 15:36             와 너무 올라서 타기 무섭다
# 8   2023.07.31 21:59                 의자는 참 좋은데..
# 9   2023.07.31 16:53                  분석글 가져왔습니다
# 10  2023.07.31 15:29          유보율 저거 다 안팔린 재고라니까
# 11  2023.07.28 14:07             바닥에서 던지는 바보들 많아
# 12  2023.07.27 11:19           원림?20대1무증?공시 임박 ?
# 13  2023.07.27 10:52                  거래정진줄 알앗는데
# 14  2023.07.26 13:19                       호재공시
# 15  2023.07.26 10:29                     더싸게 더싸게
# 16  2023.07.26 10:07  다른데 무증한다고 약팔던 애덜은  다 어디숨엇냐
# 17  2023.07.25 15:00                         딱봐도
# ...

# %%
# Extract the number of tokens used from the response
total_tokens_used = response['usage']['total_tokens']

print(f"Number of tokens used: {total_tokens_used}")
# Out:
# Number of tokens used: 130

# %%
usage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 usage
#
# NameError: name 'usage' is not defined
