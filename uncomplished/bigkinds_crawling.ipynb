# %%
#크롤링시 필요한 라이브러리 불러오기
from bs4 import BeautifulSoup
import requests
import re
import datetime
from tqdm import tqdm
import sys
import json
import jsonlines
import pprint
import time
import pandas as pd
import numpy as np

# %%
NEWS_LIST_URL = "https://www.bigkinds.or.kr/api/news/search.do"

NEWS_LIST_PAYLOAD = {"indexName":"news",
"searchKey":"암호화폐",
"searchKeys":[{}],
"byLine":"",
"searchFilterType":"1",
"searchScopeType":"1",
"searchSortType":"date",
"sortMethod":"date",
"mainTodayPersonYn":"",
"startDate":"2023-05-25",
"endDate":"2023-08-25",
"newsIds":None,
"categoryCodes":[],
"providerCodes":["01100101","01100201","01100301","01100401","01100501","01100611","01100701","01100801","01100901","01101001","01101101","02100101","02100201","02100311","02100801","02100851","02100501","02100601","02100701"],
"incidentCodes":[],
"networkNodeType":"",
"topicOrigin":"",
"dateCodes":[],
"editorialIs":False,
"startNo":2,
"resultNumber":10,
"isTmUsable":False,
"isNotTmUsable":False}

NEWS_LIST_HEADERS = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Connection": "keep-alive",
    "Content-Length": "661",
    "Content-Type": "application/json;charset=UTF-8",
    "Cookie": "Bigkinds=32265CAF60809331F0F8E6D3FEF20EB7; _gid=GA1.3.1237921437.1693188567; _ga=GA1.3.285007105.1692864667; _gat=1; _ga_QWY27BS8JM=GS1.1.1693188567.8.1.1693188645.60.0.0",
    "Host": "www.bigkinds.or.kr",
    "Origin": "https://www.bigkinds.or.kr",
    "Referer": "https://www.bigkinds.or.kr/v2/news/index.do",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest",
    "sec-ch-ua": '"Chromium";v="116", "Not)A;Brand";v="24", "Google Chrome";v="116"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows"
}

# response = requests.request("POST", 
#                                 NEWS_LIST_URL, 
#                                 headers=NEWS_LIST_HEADERS, 
#                                 data = json.dumps(NEWS_LIST_PAYLOAD))

# %%
response
# Out:
# <Response [200]>

# %%
def get_news_list_by_index(start_index=1, result_len=1000):
    NEWS_LIST_PAYLOAD.update({"startNo":start_index, "resultNumber":str(result_len)})
    response = requests.request("POST", 
                                NEWS_LIST_URL, 
                                headers=NEWS_LIST_HEADERS, 
                                data = json.dumps(NEWS_LIST_PAYLOAD))
    return response.json()


def get_news_detail(NEWS_ID):
    url = f"https://www.bigkinds.or.kr/news/detailView.do?docId={NEWS_ID}&returnCnt=1"
    response = requests.request("GET", url)
    
    # 응답 상태 코드 확인
    if response.status_code != 200:
        print(f"Error for NEWS_ID={NEWS_ID}: {response.status_code}")
        print(response.text)  # 응답 내용 출력
        return None

    try:
        return response.json()
    except json.JSONDecodeError as e:
        print(f"JSONDecodeError for NEWS_ID={NEWS_ID}: {e}")
        print(response.text)  # 에러 발생 시, 응답 내용 출력
        return None

# 샘플 NEWS_ID로 함수 테스트 (실제 실행 환경에서는 주석 처리 추천)
# sample_news_id = df_total.NEWS_ID.iloc[0].astype(int)
# get_news_detail(sample_news_id)


def write_jsonl(JSON_ARR, filename='output.jsonl'):
    with jsonlines.open(filename, mode='a') as writer:
        writer.write_all(JSON_ARR)

# %%
dfArr = []
for i in range(1,101):
    result = get_news_list_by_index(i)
    dfArr.append(pd.json_normalize(result["resultList"]))

# %%
df_total = pd.concat(dfArr)

# %%
df_total.shape
# Out:
# (635, 24)

# %%
df_total.reset_index(drop=True, inplace=True)

# %%
df_total['NEWS_ID'] = df_total['NEWS_ID'].astype(str)

# %%
search = '암호화폐'

# %%
#데이터 프레임 저장
now = datetime.datetime.now() 
df_total.to_csv('{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H시%M분%S초')),encoding='utf-8-sig',index=False)

# %%
get_news_detail(02100101.20230825170504001)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-59-065b832c0bab> in <module>
# ----> 1 get_news_detail(02100101.20230825170504001)
#
# <ipython-input-37-9eacdb367959> in get_news_detail(NEWS_ID)
#      11     url = f"https://www.bigkinds.or.kr/news/detailView.do?docId={NEWS_ID}&returnCnt=1"
#      12     response = requests.request("GET", url)
# ---> 13     return response.json()
#      14
#      15 def write_jsonl(JSON_ARR, filename='output.jsonl'):
#
# c:\Users\user\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# c:\Users\user\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# c:\Users\user\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\Users\user\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 9 column 1 (char 16)

# %%
list(df_total.NEWS_ID.items())
# Out:
# [(0, '02100101.20230825170504001'),
#  (1, '02100501.20230825094135001'),
#  (2, '02100311.20230824192036001'),
#  (3, '02100851.20230824142006001'),
#  (4, '01100801.20230824103202001'),
#  (5, '02100851.20230824070806001'),
#  (6, '02100801.20230824063138001'),
#  (7, '02100201.20230824043254001'),
#  (8, '01100801.20230824031008001'),
#  (9, '02100601.20230823180319001'),
#  (10, '01100611.20230823164825001'),
#  (11, '02100311.20230823145551001'),
#  (12, '02100601.20230823115029001'),
#  (13, '01100501.20230823110305001'),
#  (14, '02100601.20230823095305001'),
#  (15, '02100201.20230823093023001'),
#  (16, '01100611.20230823180243001'),
#  (17, '02100851.20230821065636001'),
#  (18, '01100901.20230821000829001'),
#  (19, '02100201.20230819130038002'),
#  (20, '02100701.20230819073032001'),
#  (21, '02100501.20230819071258001'),
#  (22, '02100701.20230819055255001'),
#  (23, '02100201.20230819044939001'),
#  (24, '02100201.20230819043117001'),
#  (25, '02100851.20230818173851001'),
#  (26, '01100201.20230818151335001'),
#  (27, '01100611.20230818143027001'),
#  (28, '02100201.20230818103000001'),
#  (29, '02100601.20230818095447001'),
#  (30, '01100901.20230818050234001'),
#  (31, '01100901.20230818050211001'),
#  (32, '02100601.20230817182439002'),
#  (33, '02100851.20230817090143001'),
#  (34, '02100851.20230817063259001'),
#  (35, '02100801.20230816235851001'),
#  (36, '02100601.20230816224326001'),
#  (37, '01100201.20230816171732001'),
#  (38, '02100501.20230816163240001'),
#  (39, '02100851.20230816072444001'),
#  (40, '01100901.20230815160231001'),
#  (41, '01100901.20230815050125001'),
#  (42, '01101101.20230814153158001'),
#  (43, '01100301.20230814121951004'),
#  (44, '02100601.20230813001208001'),
#  (597, '01100901.20230530170110001'),
#  (598, '01101101.20230530153653001'),
#  (599, '01100801.20230530144903001'),
#  (600, '02100601.20230530142552001'),
#  (601, '02100601.20230529183029002'),
#  (602, '02100601.20230529173126001'),
#  (603, '02100101.20230529132009001'),
#  (604, '01100901.20230529130054001'),
#  (605, '01100611.20230529103954001'),
#  (606, '02100601.20230528001542001'),
#  (607, '02100851.20230528060207001'),
#  (608, '01100301.20230527105139001'),
#  (609, '02100501.20230527075845001'),
#  (610, '02100601.20230526182221003'),
#  (611, '01100611.20230526165449001'),
#  (612, '02100311.20230526102519001'),
#  (613, '02100201.20230526075035001'),
#  (614, '01101101.20230526043018001'),
#  (615, '01100611.20230526042537001'),
#  (616, '01100901.20230526005639001'),
#  (617, '01100701.20230526001337002'),
#  (618, '02100851.20230525213656001'),
#  (619, '02100601.20230525185116003'),
#  (620, '02100601.20230525183036001'),
#  (621, '02100601.20230525182822001'),
#  (622, '02100601.20230525181233002'),
#  (623, '02100601.20230525165837001'),
#  (624, '02100601.20230525163525001'),
#  (625, '01100401.20230525160234001'),
#  (626, '02100851.20230525154143001'),
#  (627, '02100851.20230525133909001'),
#  (628, '01100501.20230525114505008'),
#  (629, '02100311.20230525105108002'),
#  (630, '02100601.20230525103558001'),
#  (631, '02100601.20230525103025001'),
#  (632, '02100801.20230525091710002'),
#  (633, '02100701.20230525080343001'),
#  (634, '02100101.20230525063002001')]

# %%
# 기사 데이터 jsonl 형식으로 저장
json_arr = []
for i, news_id in df_total.NEWS_ID.items():
    if news_id:
        res = get_news_detail(news_id)
        json_arr.append(res['detail'])
    if i % 100 == 0:
        print(i)
        write_jsonl(json_arr, 'result.jsonl')
        json_arr = []
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-57-de74ed3e4d32> in <module>
#       3 for i, news_id in df_total.NEWS_ID.items():
#       4     if news_id:
# ----> 5         res = get_news_detail(news_id)
#       6         json_arr.append(res['detail'])
#       7     if i % 100 == 0:
#
# <ipython-input-37-9eacdb367959> in get_news_detail(NEWS_ID)
#      11     url = f"https://www.bigkinds.or.kr/news/detailView.do?docId={NEWS_ID}&returnCnt=1"
#      12     response = requests.request("GET", url)
# ---> 13     return response.json()
#      14
#      15 def write_jsonl(JSON_ARR, filename='output.jsonl'):
#
# c:\Users\user\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# c:\Users\user\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# c:\Users\user\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\Users\user\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 9 column 1 (char 16)

# %%
print("Response Content:", response.text[:500])  # 응답 내용의 첫 500자 출력
# Out:
# Response Content: {"getCategoryCodeList":[{"CategoryCode":"001000000","CategoryCount":"175","CategoryName":"정치"},{"CategoryCode":"002000000","CategoryCount":"315","CategoryName":"경제"},{"CategoryCode":"003000000","CategoryCount":"62","CategoryName":"사회"},{"CategoryCode":"004000000","CategoryCount":"9","CategoryName":"문화"},{"CategoryCode":"005000000","CategoryCount":"111","CategoryName":"국제"},{"CategoryCode":"006000000","CategoryCount":"3","CategoryName":"지역"},{"CategoryCode":"008000000","CategoryCount":"233","Cate

# %%
# 응답을 BeautifulSoup 객체로 변환
soup = BeautifulSoup(response.content, 'html.parser')

# 원하는 데이터 추출
# 예: 모든 기사 제목을 가져온다고 가정할 때
titles = soup.find_all('#news-results > div:nth-child(1) > div > div.cont > a > div > strong > span')  # 클래스 이름은 실제 웹사이트의 구조에 따라 다를 수 있습니다.
for title in titles:
    print(title.text)

# %%
# 응답으로 받은 JSON 데이터 파싱
data = response.json()

# 뉴스 기사의 내용만 추출 (기대되는 JSON 구조에 따라 변경될 수 있음)
articles = []
if 'result' in data and 'list' in data['result']:
    for item in data['result']['list']:
        if 'news' in item:
            articles.append(item['news'])

# articles 리스트에 뉴스 기사 내용이 저장됩니다.
print(articles)
# Out:
# []

# %%
data
# Out:
# {'getCategoryCodeList': [{'CategoryCode': '001000000',
#    'CategoryCount': '175',
#    'CategoryName': '정치'},
#   {'CategoryCode': '002000000', 'CategoryCount': '315', 'CategoryName': '경제'},
#   {'CategoryCode': '003000000', 'CategoryCount': '62', 'CategoryName': '사회'},
#   {'CategoryCode': '004000000', 'CategoryCount': '9', 'CategoryName': '문화'},
#   {'CategoryCode': '005000000', 'CategoryCount': '111', 'CategoryName': '국제'},
#   {'CategoryCode': '006000000', 'CategoryCount': '3', 'CategoryName': '지역'},
#   {'CategoryCode': '008000000',
#    'CategoryCount': '233',
#    'CategoryName': 'IT_과학'}],
#  'documentCount': 10,
#  'totalCntNotAnalysis': 9,
#  'errorMessage': None,
#  'errorCode': None,
#  'totalCntAnalysis': 626,
#  'totalCount': 635,
#  'getDateCodeList': [{'date': '2023', 'dateCount': '635'}],
#  'getIncidentCodeList': [{'IncidentName': '범죄',
#    'IncidentCount': '158',
#    'IncidentCode': '1'},
#   {'IncidentName': '사고', 'IncidentCount': '19', 'IncidentCode': '2'},
#   {'IncidentName': '재해', 'IncidentCount': '4', 'IncidentCode': '3'},
#   {'IncidentName': '사회', 'IncidentCount': '10', 'IncidentCode': '4'}],
#  'isLimitPage': False,
#  'success': True,
#  'getProviderCodeList': [{'ProviderName': '경향신문',
#    'ProviderCount': '5',
#    'ProviderCode': '01100101',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '국민일보',
#    'ProviderCount': '16',
#    'ProviderCode': '01100201',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '내일신문',
#    'ProviderCount': '5',
#    'ProviderCode': '01100301',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '동아일보',
#    'ProviderCount': '13',
#    'ProviderCode': '01100401',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '매일경제',
#    'ProviderCount': '27',
#    'ProviderCode': '02100101',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'},
#   {'ProviderName': '머니투데이',
#    'ProviderCount': '60',
#    'ProviderCode': '02100201',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'},
#   {'ProviderName': '문화일보',
#    'ProviderCount': '7',
#    'ProviderCode': '01100501',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '서울경제',
#    'ProviderCount': '32',
#    'ProviderCode': '02100311',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'},
#   {'ProviderName': '서울신문',
#    'ProviderCount': '38',
#    'ProviderCode': '01100611',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '세계일보',
#    'ProviderCount': '37',
#    'ProviderCode': '01100701',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '아시아경제',
#    'ProviderCount': '25',
#    'ProviderCode': '02100801',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'},
#   {'ProviderName': '아주경제',
#    'ProviderCount': '62',
#    'ProviderCode': '02100851',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'},
#   {'ProviderName': '조선일보',
#    'ProviderCount': '17',
#    'ProviderCode': '01100801',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '중앙일보',
#    'ProviderCount': '58',
#    'ProviderCode': '01100901',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '파이낸셜뉴스',
#    'ProviderCount': '39',
#    'ProviderCode': '02100501',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'},
#   {'ProviderName': '한겨레',
#    'ProviderCount': '3',
#    'ProviderCode': '01101001',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '한국경제',
#    'ProviderCount': '160',
#    'ProviderCode': '02100601',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'},
#   {'ProviderName': '한국일보',
#    'ProviderCount': '7',
#    'ProviderCode': '01101101',
#    'ProviderGubunCode': '10',
#    'ProviderGubunName': '전국일간지'},
#   {'ProviderName': '헤럴드경제',
#    'ProviderCount': '24',
#    'ProviderCode': '02100701',
#    'ProviderGubunCode': '20',
#    'ProviderGubunName': '경제일간지'}],
#  'resultList': [{'CATEGORY_INCIDENT': '1 8 30',
#    'BYLINE': '임병선',
#    'byLine': '임병선',
#    'PROVIDER_SUBJECT': '국제\n국제\n미국·중남미',
#    'IMAGES_CAPTION': '베이지색 미결수 죄수복에 다리 교정기를 차고 나온 샘 뱅크먼프리드\n법정 스케치 로이터 연합뉴스',
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': '사회>사건_사고<font color=Gray> | </font>국제>아시아<font color=Gray> | </font>국제>유럽_EU',
#    'CATEGORY_INCIDENT_NAMES': '범죄>범죄일반>사기',
#    'PROVIDER_NEWS_ID': '01100611.20230823500218',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '',
#    'DATE': '20230823',
#    'PRINTING_PAGE': '',
#    'NEWS_ID': '01100611.20230823164825001',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/01100611/2023/08/23/01100611.20230823164825001.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '003000000 003006000\n005000000 005006000\n005000000 005008000',
#    'PROVIDER_LINK_PAGE': 'http://www.seoul.co.kr/news/newsView.php?id=20230823500218',
#    'PROVIDER': '서울신문',
#    'TITLE': '‘암호화폐의 왕’이었는데 채식주의자 뱅크먼프리드 “빵과 물로 연명”',
#    'PROVIDER_CODE': '01100611',
#    'CONTENT': '가상화폐 사기 등 혐의로 수감 중인 코인거래소 FTX 창업자 샘 뱅크먼프리드(31)가 구치소에서 빵과 물로만 버티고 있다고 그의 변호사가 딱한 사정을 알렸다.<br/>22일(현지시간) 영국 BBC 방송에 따르면 그의 변호사는 뉴욕 맨해튼 연방법원 심리에서 구치소가 채식을 제공하지 않아 의뢰인이 “글자 그대로 빵과 물로 연명하고 있다”고 호소했다. 또한 주의력 ..'},
#   {'CATEGORY_INCIDENT': '',
#    'BYLINE': '이덕연 기자',
#    'byLine': '이덕연 기자',
#    'PROVIDER_SUBJECT': '산업\n중기·벤처\n벤처·스타트업',
#    'IMAGES_CAPTION': '',
#    'EXTENSION': 'png',
#    'CATEGORY_NAMES': 'IT_과학>콘텐츠',
#    'CATEGORY_INCIDENT_NAMES': '',
#    'PROVIDER_NEWS_ID': '29TIPZZ84P',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '0',
#    'DATE': '20230823',
#    'PRINTING_PAGE': '0',
#    'NEWS_ID': '02100311.20230823145551001',
#    'SUB_TITLE': '미국 1위 암호화폐 거래소 코인베이스와 협업',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/02100311/2023/08/23/02100311.20230823145551001.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '008000000 008004000',
#    'PROVIDER_LINK_PAGE': 'http://www.sedaily.com/NewsView/29TIPZZ84P',
#    'PROVIDER': '서울경제',
#    'TITLE': "이스크라, 글로벌 유저 대상 '클래시몬' 게임 NFT 무료 배포",
#    'PROVIDER_CODE': '02100311',
#    'CONTENT': '웹3 블록체인 게임 플랫폼 ‘이스크라’가 이달 28일부터 글로벌 유저를 대상으로 ‘클래시몬’ 게임 NFT 프리민팅(무료 배포)을 실시한다고 23일 밝혔다. <br/> <br/><br/> 이번 무료 배포 행사는 미국 1위 암호화폐 거래소 코인베이스와의 협업을 통해 약 1주일 동안 진행된다. 이용자들은 클래시몬 게임 내에서 미스터리 박스를 개봉하고 캐릭터 NTF와 각종 장구류와..'},
#   {'CATEGORY_INCIDENT': '1 6 22',
#    'BYLINE': '김인엽',
#    'byLine': '김인엽',
#    'PROVIDER_SUBJECT': '',
#    'IMAGES_CAPTION': '자오창펑 바이낸스 CEO가 지난해 6월 프랑스 파리에서 열린 비바 테크놀로지 콘퍼런스에서 연설하고 있다. /로이터',
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': '경제>외환<font color=Gray> | </font>국제>러시아<font color=Gray> | </font>국제>미국_북미',
#    'CATEGORY_INCIDENT_NAMES': '범죄>기업범죄>내부자거래',
#    'PROVIDER_NEWS_ID': '202308232256i',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '',
#    'DATE': '20230823',
#    'PRINTING_PAGE': '',
#    'NEWS_ID': '02100601.20230823115029001',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/02100601/2023/08/23/02100601.20230823115029001.01',
#    'KPF_ABUSING_NEWS': '02100601.20230823180319001',
#    'KPF_ABUSING_NEWS_IS': 'TRUE',
#    'CATEGORY': '002000000 002002000\n005000000 005005000\n005000000 005003000',
#    'PROVIDER_LINK_PAGE': 'https://www.hankyung.com/international/article/202308232256i',
#    'PROVIDER': '한국경제',
#    'TITLE': '"바이낸스, 루블화→암호화폐 세탁 방치했다" 美 수사 착수',
#    'PROVIDER_CODE': '02100601',
#    'CONTENT': '세게 최대 암호화폐 거래소인 바이낸스가 대러시아 금융 제재 위반 혐의로 미국 정부의 수사선상에 올랐다. <br/> <br/> 월스트리트저널(WSJ)은 22일(현지시간) 내부 소식통을 인용해 미 법무부가 대러시아 제재 위반 가능성과 관련해 바이낸스를 수사하고 있다고 전했다. 법무부는 서방 제재로 국제 송금 및 환전이 금지된 러시아 루블화를 자금세탁하는 통로로 바이낸스가..'},
#   {'CATEGORY_INCIDENT': '',
#    'BYLINE': '조해동',
#    'byLine': '조해동',
#    'PROVIDER_SUBJECT': '408',
#    'IMAGES_CAPTION': '',
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': '경제>외환<font color=Gray> | </font>국제>중국<font color=Gray> | </font>국제>일본',
#    'CATEGORY_INCIDENT_NAMES': '',
#    'PROVIDER_NEWS_ID': '01100501.2023082301039905015001',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '0',
#    'DATE': '20230823',
#    'PRINTING_PAGE': '0',
#    'NEWS_ID': '01100501.20230823110305001',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/01100501/2023/08/23/01100501.20230823110305001.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '002000000 002002000\n005000000 005002000\n005000000 005001000',
#    'PROVIDER_LINK_PAGE': 'http://www.munhwa.com/news/view.html?no=2023082301039905015001',
#    'PROVIDER': '문화일보',
#    'TITLE': '글로벌 통화 전쟁의 과거와 현재, 그리고 미래를 조망하다!',
#    'PROVIDER_CODE': '01100501',
#    'CONTENT': '이철환의 신간, ‘달러의 시대는 저무는가? 달러 위안 유로 엔 파운드화, 금 암호화폐의 미래’(다락방, 2023)에 쏠리는 시선<br/><br/><br/><br/>국제금융시장이 요동치고 있다. 2차 세계대전 이후 형성된 미 달러화의 강력한 패권(헤게모니)이 서서히 약화하고, 세계 2위의 경제 대국으로 올라선 중국 위안화의 힘이 강해지는가 싶더니 최근에는 미·중 갈등 속에 중국 위안..'},
#   {'CATEGORY_INCIDENT': '',
#    'BYLINE': '조미현',
#    'byLine': '조미현',
#    'PROVIDER_SUBJECT': '',
#    'IMAGES_CAPTION': '\n',
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': '경제>증권_증시<font color=Gray> | </font>경제>부동산',
#    'CATEGORY_INCIDENT_NAMES': '',
#    'PROVIDER_NEWS_ID': '202308231810i',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '',
#    'DATE': '20230823',
#    'PRINTING_PAGE': '',
#    'NEWS_ID': '02100601.20230823095305001',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/02100601/2023/08/23/02100601.20230823095305001.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '002000000 002006000\n002000000 002010000',
#    'PROVIDER_LINK_PAGE': 'https://www.hankyung.com/economy/article/202308231810i',
#    'PROVIDER': '한국경제',
#    'TITLE': '"이더리움 선물 ETF 美 승인 \'청신호\' 켜졌다" [한경 코알라]',
#    'PROVIDER_CODE': '02100601',
#    'CONTENT': "코인, 알고 투자하라! <br/>한국경제신문의 암호화폐 투자 뉴스레터 '코알라'에 실린 기사입니다. <br/>매주 수요일 아침 발행하는 코알라를 받아보세요! <br/>무료 구독신청 hankyung.com/newsletter <br/> <br/>미국 증권거래위원회(SEC)가 비트코인(BTC) 현물 상장지수펀드(ETF)보다 이더리움(ETH) 선물 ETF를 먼저 승인할 것이란 전망이 제기됐다..."},
#   {'CATEGORY_INCIDENT': '1 8 30',
#    'BYLINE': '남미래|기자|',
#    'byLine': '남미래|기자|',
#    'PROVIDER_SUBJECT': 'O0101',
#    'IMAGES_CAPTION': '\n\n팀블랙버드 직원들/사진제공=팀블랙버드',
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': 'IT_과학>보안<font color=Gray> | </font>IT_과학>모바일<font color=Gray> | </font>경제>반도체',
#    'CATEGORY_INCIDENT_NAMES': '범죄>범죄일반>사기',
#    'PROVIDER_NEWS_ID': '2023081417015674137',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '',
#    'DATE': '20230823',
#    'PRINTING_PAGE': '',
#    'NEWS_ID': '02100201.20230823093023001',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/02100201/2023/08/23/02100201.20230823093023001.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '008000000 008002000\n008000000 008003000\n002000000 002009000',
#    'PROVIDER_LINK_PAGE': 'http://news.moneytoday.co.kr/view/mtview.php?no=2023081417015674137&type=2',
#    'PROVIDER': '머니투데이',
#    'TITLE': '"매일 1조 들락, 이상해" FTX사태 예견…K-스타트업 찾아온 시카고 거래소',
#    'PROVIDER_CODE': '02100201',
#    'CONTENT': '[머니투데이 남미래 기자] [스타트UP스토리] 주기영 팀블랙버드 대표<br/><br/>[이 기사에 나온 스타트업에 대한 보다 다양한 기업정보는 유니콘팩토리 빅데이터 플랫폼 \'데이터랩\'에서 볼 수 있습니다.] <br/><br/> "크립토퀀트는 암호화폐 시장의 블룸버그입니다."<br/><br/>주기영 팀블랙버드 대표는 자사가 운영하는 블록체인 데이터 분석 서비스 \'크립토퀀트\'에 대해 이같이 말했다...'},
#   {'CATEGORY_INCIDENT': '',
#    'BYLINE': '유규상',
#    'byLine': '유규상',
#    'PROVIDER_SUBJECT': '사설·오피니언\n오피니언\n오늘의 눈',
#    'IMAGES_CAPTION': '유규상 경제부 기자',
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': '미분류',
#    'CATEGORY_INCIDENT_NAMES': '',
#    'PROVIDER_NEWS_ID': '01100611.20230823005002',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '5',
#    'DATE': '20230823',
#    'PRINTING_PAGE': '5',
#    'NEWS_ID': '01100611.20230823180243001',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/01100611/2023/08/23/01100611.20230823180243001.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '999999999',
#    'PROVIDER_LINK_PAGE': 'http://www.seoul.co.kr/news/newsView.php?id=20230823005002',
#    'PROVIDER': '서울신문',
#    'TITLE': '[오늘의 눈] 기득권에 대한 불신 더 커진 청년층/유규상 경제부 기자',
#    'PROVIDER_CODE': '01100611',
#    'CONTENT': '소시에테제네랄(SG)증권발 주가 폭락 사태, 김남국 의원의 가상자산(암호화폐) 보유 논란 이후 정부와 국회는 각종 대책을 쏟아내고 있지만 시장에 대한 청년층의 신뢰를 회복하기에는 한마디로 역부족이다.<br/>먼저 SG증권발 주가 폭락 사태 이후 금융당국은 불공정거래 차단 등을 내세우며 적극적으로 조치했다. 그러나 주식시장에는 소셜미디어(SNS)의 익명성과 규제..'},
#   {'CATEGORY_INCIDENT': '',
#    'BYLINE': '배근미\n배근미·강일용',
#    'byLine': '배근미\n배근미·강일용',
#    'PROVIDER_SUBJECT': '아주경제\n금융\n암호화폐',
#    'IMAGES_CAPTION': '[사진=아주경제DB]',
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': 'IT_과학>보안<font color=Gray> | </font>IT_과학>콘텐츠<font color=Gray> | </font>IT_과학>모바일',
#    'CATEGORY_INCIDENT_NAMES': '',
#    'PROVIDER_NEWS_ID': '20230821063848365',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '',
#    'DATE': '20230821',
#    'PRINTING_PAGE': '',
#    'NEWS_ID': '02100851.20230821065636001',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/02100851/2023/08/21/02100851.20230821065636001.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '008000000 008002000\n008000000 008004000\n008000000 008003000',
#    'PROVIDER_LINK_PAGE': 'https://www.ajunews.com/view/20230821063848365',
#    'PROVIDER': '아주경제',
#    'TITLE': "[아주경제 코이너스 브리핑] '주말 폭락' 비트코인, 2만6171달러대···소폭 반등세",
#    'PROVIDER_CODE': '02100851',
#    'CONTENT': "[사진=아주경제DB] <br/>◆ '주말 폭락' 비트코인, 2만6171달러대 거래···소폭 반등 <br/> <br/>지난 주말 2만9000달러대에서 2만6000달러 수준까지 급락한 비트코인이 소폭 반등하고 있다. <br/> <br/>21일 글로벌 가상자산 중계 사이트 코인마켓캡에 따르면 비트코인은 이날 오전 6시 50분 기준 전일 대비 0.35% 오른 2만6171달러 안팎에서 거래되고 있.."},
#   {'CATEGORY_INCIDENT': '',
#    'BYLINE': '정영교.박현주(chung.yeonggyo@joongang.co.kr)',
#    'byLine': '정영교.박현주(chung.yeonggyo@joongang.co.kr)',
#    'PROVIDER_SUBJECT': '',
#    'IMAGES_CAPTION': '',
#    'CATEGORY_NAMES': '정치>북한<font color=Gray> | </font>정치>외교<font color=Gray> | </font>IT_과학>보안',
#    'CATEGORY_INCIDENT_NAMES': '',
#    'PROVIDER_NEWS_ID': '25186035',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': 'A4',
#    'DATE': '20230821',
#    'PRINTING_PAGE': 'A4',
#    'NEWS_ID': '01100901.20230821000829001',
#    'SUB_TITLE': '',
#    'IMAGES': '',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '001000000 001001000\n001000000 001003000\n008000000 008002000',
#    'PROVIDER_LINK_PAGE': 'https://www.joongang.co.kr/article/25186035',
#    'PROVIDER': '중앙일보',
#    'TITLE': '북 인권·사이버 돈줄 조준…한미일, 김정은 아픈곳 찌른다',
#    'PROVIDER_CODE': '01100901',
#    'CONTENT': '한국·미국·일본이 함께 ‘사이버 범죄 차단’ 카드를 꺼내 김정은 북한 국무위원장의 제일 아픈 곳을 정확히 찔렀다. 윤석열 대통령과 조 바이든 미국 대통령, 기시다 후미오 일본 총리는 18일(현지시간) 발표한 ‘캠프 데이비드 정신’에서 “불법적인 대량살상무기(WMD) 및 탄도미사일 프로그램의 자금원으로 사용되는 북한의 불법 사이버 활동에 대해 우려를 표명..'},
#   {'CATEGORY_INCIDENT': '1 8 30',
#    'BYLINE': '김성휘|기자|',
#    'byLine': '김성휘|기자|',
#    'PROVIDER_SUBJECT': 'T0201',
#    'IMAGES_CAPTION': "손정의 소프트뱅크 회장\n(워싱턴 로이터=뉴스1) 김성식 기자 = 챗GPT를 개발한 샘 알트먼 오픈AI 최고경영자(CEO)가 16일(현지시간) 미국 상원 법사위원회 청문회에 참석해 발언하고 있다. 2023.05.16.ⓒ 로이터=뉴스1 Copyright (C) 뉴스1. All rights reserved. 무단 전재 및 재배포 금지.\n\n(서울=뉴스1) 이승배 기자 = 창펑자오 바이낸스 CEO가 2019년 4월4일 오전 서울 중구 장충체육관에서 열린 '제2회 분산경제포럼(디코노미2019)'에 참석해 발표하고 있다. 2019.4.4/뉴스1",
#    'EXTENSION': 'jpg',
#    'CATEGORY_NAMES': '경제>산업_기업<font color=Gray> | </font>경제>증권_증시<font color=Gray> | </font>경제>자동차',
#    'CATEGORY_INCIDENT_NAMES': '범죄>범죄일반>사기',
#    'PROVIDER_NEWS_ID': '2023081820192759473',
#    'KPF_GABAGE_NEWS_IS': 'FALSE',
#    'printingPage': '',
#    'DATE': '20230819',
#    'PRINTING_PAGE': '',
#    'NEWS_ID': '02100201.20230819130038002',
#    'SUB_TITLE': '',
#    'IMAGES': 'https://www.bigkinds.or.kr/resources/images/02100201/2023/08/19/02100201.20230819130038002.01',
#    'KPF_ABUSING_NEWS': '',
#    'KPF_ABUSING_NEWS_IS': 'FALSE',
#    'CATEGORY': '002000000 002005000\n002000000 002006000\n002000000 002011000',
#    'PROVIDER_LINK_PAGE': 'http://news.moneytoday.co.kr/view/mtview.php?no=2023081820192759473&type=2',
#    'PROVIDER': '머니투데이',
#    'TITLE': '손정의, 사기 당했나...스타트업 투자실패 후 소송 "1.5억불 내놔"',
#    'PROVIDER_CODE': '02100201',
#    'CONTENT': "[머니투데이 김성휘 기자] [글로벌 스타트업씬] 8월 3주차 핫뉴스<br/><br/>[편집자주] '글로벌 스타트업씬'은 한주간 발생한 주요 글로벌 벤처캐피탈(VC) 및 스타트업 소식을 전달하는 코너입니다. 이에 더해 국내 스타트업 시장에 미칠 영향과 전망까지 짚어드립니다.<br/><br/> <br/>손정의(손 마사요시) 일본 소프트뱅크 회장이 소셜앱 스타트업 투자에 실패, 투자금 반환 소.."}],
#  'gubunCodeList': ['10', '20']}
